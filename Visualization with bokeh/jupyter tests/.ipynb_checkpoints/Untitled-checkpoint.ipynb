# %%
import pandas
from bokeh.plotting import figure, output_file, show

df =  pandas.read_csv("adbe.csv", parse_dates = ["Date"])
p = figure(width = 500,  height = 500, x_axis_type = "datetime", sizing_mode = "stretch_both")
p.line(df["Date"], df["Close"], color = "Orange", alpha = 0.5)
output_file("Datetime.html")
show(p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-c59ddec438d9> in <module>()
#       3
#       4 df =  pandas.read_csv("adbe.csv", parse_dates = ["Date"])
# ----> 5 p = figure(width = 500,  height = 500, x_axis_type = "datetime", sizing_mode = True)
#       6 p.line(df["Date"], df["Close"], color = "Orange", alpha = 0.5)
#       7 output_file("Datetime.html")
#
# c:\users\nisha\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\plotting\figure.py in figure(**kwargs)
#     962     '''
#     963
# --> 964     return Figure(**kwargs)
#     965
#     966
#
# c:\users\nisha\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\plotting\figure.py in __init__(self, *arg, **kw)
#     143             kw['title'] = Title(text=title)
#     144
# --> 145         super(Figure, self).__init__(*arg, **kw)
#     146
#     147         self.x_range = _get_range(opts.x_range)
#
# c:\users\nisha\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\models\plots.py in __init__(self, **kwargs)
#      46             kwargs["toolbar"] = Toolbar(tools=tools, logo=logo)
#      47
# ---> 48         super(LayoutDOM, self).__init__(**kwargs)
#      49
#      50     def select(self, *args, **kwargs):
#
# c:\users\nisha\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\model.py in __init__(self, **kwargs)
#     217         self._id = kwargs.pop("id", make_id())
#     218         self._document = None
# --> 219         super(Model, self).__init__(**kwargs)
#     220         default_theme.apply_to_model(self)
#     221
#
# c:\users\nisha\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\core\has_props.py in __init__(self, **properties)
#     234
#     235         for name, value in properties.items():
# --> 236             setattr(self, name, value)
#     237
#     238     def __setattr__(self, name, value):
#
# c:\users\nisha\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\core\has_props.py in __setattr__(self, name, value)
#     261
#     262         if name in props or (descriptor is not None and descriptor.fset is not None):
# --> 263             super(HasProps, self).__setattr__(name, value)
#     264         else:
#     265             matches, text = difflib.get_close_matches(name.lower(), props), "similar"
#
# c:\users\nisha\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\core\property\descriptors.py in __set__(self, obj, value, setter)
#     501             raise RuntimeError("%s.%s is a readonly property" % (obj.__class__.__name__, self.name))
#     502
# --> 503         self._internal_set(obj, value, setter=setter)
#     504
#     505     def __delete__(self, obj):
#
# c:\users\nisha\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\core\property\descriptors.py in _internal_set(self, obj, value, hint, setter)
#     722
#     723         '''
# --> 724         value = self.property.prepare_value(obj, self.name, value)
#     725
#     726         old = self.__get__(obj, obj.__class__)
#
# c:\users\nisha\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\core\property\bases.py in prepare_value(self, obj_or_cls, name, value)
#     283                     break
#     284             else:
# --> 285                 raise e
#     286         else:
#     287             value = self.transform(value)
#
# c:\users\nisha\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\core\property\bases.py in prepare_value(self, obj_or_cls, name, value)
#     276     def prepare_value(self, obj_or_cls, name, value):
#     277         try:
# --> 278             self.validate(value)
#     279         except ValueError as e:
#     280             for tp, converter in self.alternatives:
#
# c:\users\nisha\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\core\properties.py in validate(self, value, detail)
#     738
#     739     def validate(self, value, detail=True):
# --> 740         super(Enum, self).validate(value, detail)
#     741
#     742         if not (value is None or value in self._enum):
#
# c:\users\nisha\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\core\property\bases.py in validate(self, value, detail)
#     408                 nice_join([ cls.__name__ for cls in self._underlying_type ]), value, type(value).__name__
#     409             )
# --> 410             raise ValueError(msg)
#     411
#     412     def from_json(self, json, models=None):
#
# ValueError: expected a value of type str, got True of type bool
